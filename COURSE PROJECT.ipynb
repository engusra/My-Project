# %% [markdown]
# ## __UNIVERSITY OF GHANA__
# ## EINSTEIN ADUM NGUSRA
# ## 11258376
# ##  DEPARTMENT OF BIOMEDICAL ENGINEERING
# ---

# %% [markdown]
# * ### __Importing necessary libraries__
# ---

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# * ### __Using OOP Approach__
# ---

# %%
class modified_redWine:
  
    def __init__(self,dataset):
        self.dataset=pd.read_csv(dataset)
        
    def fillNull(self):
        return self.dataset.fillna(self.dataset.mean(), inplace = True, )
       
    def remove_duplicates(self):
        return data.dataset.drop_duplicates(inplace=True)
    
    def preview_head(self):
        return self.dataset.head(10)

    def preview_tail(self):
        return self.dataset.tail(20)

    def checking_info(self):
        return self.dataset.info()

    def data_description(self):
        return self.dataset.describe()

    def bar(self):
        
        plt.figure(figsize=(8,6))
        plt.bar(self.dataset['alcohol'],self.dataset['quality'],width=0.05, color='skyblue', edgecolor= 'black', linewidth=1)
        plt.xlabel('alcohol')
        plt.ylabel('quality')
        plt.title('Quality vrs. Alcohol')
       
        
        plt.show()

    def scatter(self):
        plt.figure(figsize=(8,6))
        plt.scatter(self.dataset['pH'],self.dataset['citric acid'], color='green',alpha=0.5)
        plt.title('Scatter Plot of Citric Acid Vs. pH')
        plt.xlabel('pH')
        plt.ylabel('Citric Acid')
        plt.show()
        
    def correlation_plot(self):
        correlation = self.dataset.corr()

        plt.figure(figsize=(8, 6))
        plt.imshow(correlation, cmap='coolwarm', interpolation='nearest')
        plt.colorbar()
        plt.title('Correlation Plot')
        plt.xticks(range(len(correlation)),correlation.columns, rotation=90)
        plt.yticks(range(len(correlation)),correlation.columns)
        plt.tight_layout()
        plt.show()

    def hist(self):
        plt.figure(figsize=(8, 6))
        column= input('Enter column name:  ' )
        plt.hist(self.dataset[column], bins=20, edgecolor='black')
        plt.xlabel(column)
        plt.title(f'Histogram of {column}')
        plt.show()
        
data = modified_redWine('Modified_red_wine.csv')

# %% [markdown]
# * ### __Red Wine Dataset__
# ---

# %%
data.dataset
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %% [markdown]
# * ### __Replacing All Null Values with Their Respective Column Mean__
# ---

# %%
data.fillNull()

# %% [markdown]
# * ### __Removing All Duplicates In The Dataset__
# ---

# %%
data.remove_duplicates()

# %% [markdown]
# * ### __Previewing First 10 rows__
# ---

# %%
data.preview_head()
# Out:
#     fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             7.4              0.70         0.00             1.9   0.076000
# 1             7.8              0.88         0.00             2.6   0.098000
# 2             7.8              0.76         0.04             2.3   0.092000
# 3            11.2              0.28         0.56             1.9   0.075000
# 5             7.4              0.66         0.00             1.8   0.075000
# 6             7.9              0.60         0.06             1.6   0.087476
# 7             7.3              0.65         0.00             1.2   0.065000
# 8             7.8              0.58         0.02             2.0   0.073000
# 9             7.5              0.50         0.36             6.1   0.071000
# 10            6.7              0.58         0.08             1.8   0.097000
#
#     free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %% [markdown]
# * ### __Previewing The Last 20__
# ---

# %%
data.preview_tail()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1577            6.2             0.700         0.15             5.1      0.076
# 1578            6.8             0.670         0.15             1.8      0.118
# 1579            6.2             0.560         0.09             1.7      0.053
# 1580            7.4             0.350         0.33             2.4      0.068
# 1582            6.1             0.715         0.10             2.6      0.053
# 1583            6.2             0.460         0.29             2.1      0.074
# 1584            6.7             0.320         0.44             2.4      0.061
# 1585            7.2             0.390         0.44             2.6      0.066
# 1586            7.5             0.310         0.41             2.4      0.065
# 1587            5.8             0.610         0.11             1.8      0.066
# 1588            7.2             0.660         0.33             2.5      0.068
# ...

# %% [markdown]
# * ### __Checking Basic Info Of The Dataset__
# ---

# %%
data.checking_info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1360 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1360 non-null   float64
#  1   volatile acidity      1360 non-null   float64
#  2   citric acid           1360 non-null   float64
#  3   residual sugar        1360 non-null   float64
#  4   chlorides             1360 non-null   float64
#  5   free sulfur dioxide   1360 non-null   float64
#  6   total sulfur dioxide  1360 non-null   float64
#  7   density               1360 non-null   float64
#  8   pH                    1360 non-null   float64
#  9   sulphates             1360 non-null   float64
#  10  alcohol               1360 non-null   float64
#  11  quality               1360 non-null   float64
# dtypes: float64(12)
# memory usage: 138.1 KB

# %% [markdown]
# * ### __Describing The Dataframe__
# ---

# %%
data.data_description()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1360.000000       1360.000000  1360.000000     1360.000000
# mean        8.310013          0.529443     0.272500        2.523235
# std         1.735778          0.182947     0.195562        1.351830
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.430000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1360.000000          1360.000000           1360.000000  1360.000000
# mean      0.088128            15.893285             46.843750     0.996710
# std       0.049351            10.443426             33.403084     0.001869
# ...

# %% [markdown]
# * ### __Plotting Bar Graph__
# ---

# %%
data.bar()

# %% [markdown]
# * ### __Plotting Histogram Of Some Columns__
#   ---

# %%
data.hist()
# Out:
# Enter column name:   fixed acidity

# %% [markdown]
# #### Majority of the red wines having fixed acidity values clustered  between the ranges of 6 and 10. This suggest a concentration of wine with
#
# #### moderate  fixed acidiy levels whilst very few are extremely low and few are extremely high

# %%
data.hist()
# Out:
# Enter column name:   volatile acidity

# %% [markdown]
# #### The histogram of the volatile acidity indicates a right-skewed distribution with a majority of wine showing lower levels of volatile acidity.
#
# #### There are fewer instances of wine with elevated volatile acidity indicating that the data set predonminantly consist of wines with a moderate to
#
# #### low votatile acidity profile

# %%
data.hist()
# Out:
# Enter column name:   citric acid

# %% [markdown]
# ####  The histogram of the citric acid in the red wine dataset displays a slightly right-skewed distribution indicating a commonness of wines with
#
# #### lower to moderate citric acid levels. The dataset exhibit a concentration of wines with citric acid levels clustered around the central range with
#
# #### fewer instances of wine displaying exceptionally high citric acid levels

# %%
data.hist()
# Out:
# Enter column name:   residual sugar

# %% [markdown]
# #### The histogram of the residual sugar demonstrate a right-skewed distribution showcasing a predominant concentration of wine with lower residual sugar
#
# #### content whilst there are few instances with high reidual sugar levels

# %%
data.hist()
# Out:
# Enter column name:   chlorides

# %% [markdown]
# #### The histgram of the chlorides reveals a positively skewed distribution indicating majority of wine having lower chloride concentration. The dataset
#
# #### shows concentration of wines with chlorides clustered around lower values whilst fewer instances exhibit higher chloride content

# %% [markdown]
# * ### __Plotting Scatter Diagram__
# ---

# %%
data.hist()
# Out:
# Enter column name:   free sulfur dioxide

# %% [markdown]
# #### The histogram of the free sulfur dioxide illustrates a right sqewed distribution emphasizing on a predominant occurance of wines with lower levels
#
# #### free sulfur dioxide

# %%
data.scatter()

# %% [markdown]
# * ### __Doing Correlation__
# ---

# %%
data.correlation_plot()

# %% [markdown]
# ## __A Report On The Plots And Graphs Obtained__
#  _ _ _

# %% [markdown]
# ### __1__. __Bar Graph Of Quality Against Alcohol__

# %% [markdown]
#  * #### __*The key observations I made are listed below*__:
#  #####
#
#
# __A__.  Most wines got ratings between 5 and 7, with fewer wines at the very good or very bad ends.
#
# __B__. Wines with medium alcohol levels, usually between 10% and 13%, often got higher quality ratings. This hints at a possible connection between moderate alcohol and better-tasting wine.
#
# __C__. Wines with more than 13% alcohol had a mix of good and not-so-good ratings. This shows that just having more alcohol doesn't always mean better quality.
#
# __D__. Some wines with less alcohol (below 10%) got super high ratings. These are interesting and might be worth looking into to find out what makes them special.
#
# ######
#
#
#
# * #### __*Analysis*__:
# The pattern we saw suggests that the relationship between wine quality and alcohol isn't straightforward. Medium alcohol levels usually mean better quality, but higher alcohol doesn't guarantee that. Different things like the type of grapes or how the wine is made could be affecting this.
#
# ######
#
#
# * #### __*Conclusion*__:
# So, in summary, this study gives us ideas about how alcohol and quality connect in red wines. It points out that having a moderate amount of alcohol generally makes wine taste better. But, there are exceptions, and looking at more details could help us understand the whole picture better.
#
#   ---

# %% [markdown]
# ## __2.__ __A Scatter Diagram Of Citric Acid Against PH__
# * #### __*The key observations I made are listed below*__:
# ####
#
# __A.__ The chart shows a wide range of pH values in the red wine samples, from more acidic to less acidic.
#
# __B.__ The amount of citric acid varies a lot among the wines, with some having low levels and others having high levels. This shows the complex mix of citric acid in the data.
#
# __C.__ Looking at the chart, there seems to be a possible negative connection between pH and citric acid levels. This means that when citric acid is high, pH tends to be low, showing a subtle relationship.
#
# __D.__ Some wines stand out on the chart, not following the general trend. Exploring these outliers could reveal unique features or differences in the data.
#
# ######
#
#
#
# * #### __*Analysis*__:
# The potential negative connection suggests that citric acid might play a big role in how acidic red wines are. Wines with more citric acid seem to have lower pH, indicating a possible acidifying effect. It's important to note that other acids, like tartaric or malic acid, could also impact overall acidity.
#
# #####
#
# * #### __*Conclusion*__:
# This analysis gives a clear picture of how pH and citric acid are linked in red wines. The possible negative connection suggests citric acid affects the acidity of these wines. Exploring more, considering other factors, and looking into outliers could help us understand the details of the red wine data even better.
#
# ---

# %% [markdown]
# ## __3. Correlation__
#
# #### __*Observations Made*__:

# %% [markdown]
# * Better red wines usually have more alcohol. If a red wine has higher alcohol, it often gets a better quality rating, showing a clear link between these two.
#
# * The chart shows detailed connections among acidity factors. Citric acid is linked to lower pH, and volatile acidity is linked to lower quality, emphasizing how specific acids affect how we taste wine.
#
# * Red wines with higher residual sugar tend to be rated better. If a red wine has a bit more residual sugar, people are likely to think it's of higher quality.
#
# * Quality and alcohol content are strongly connected. This suggests that having more alcohol in red wines significantly improves how people perceive their quality. Winemakers can use this link to adjust alcohol levels and make better wines.
#
# * The negative link between citric acid and pH shows that citric acid affects how acidic red wines are. By adjusting citric acid, winemakers can control acidity levels for a well-balanced wine.
#
# * A bit more residual sugar is linked to better quality in red wines. This discovery encourages winemakers to try different sweetness levels to suit different tastes.
#
# To conclude these connections in red wine helps winemakers and fans make smarter choices, making red wine taste better.
